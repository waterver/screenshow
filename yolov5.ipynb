# %% [markdown]
# <a href="https://colab.research.google.com/github/waterver/screenshow/blob/main/yolov5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
torch.__version__
torch.cuda.is_available()
# Out:
# True

# %%
# !nvidia-smi
# Out:
# Tue Apr  6 07:12:55 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
from google.colab import drive
drive.mount("/content/drive")
# torch.hub.list('ultralytics/yolov5')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/yolo
# Out:
# /content/drive/MyDrive/yolo

# %%
#!git clone https://github.com/ultralytics/yolov5.git
# %cd ./yolov5
# !pip install -U -r requirements.txt
# Out:
# /content/drive/My Drive/yolo/yolov5
# ...
#      |████████████████████████████████| 10.3MB 9.7MB/s
# ...
#      |████████████████████████████████| 15.3MB 177kB/s
# ...
#      |████████████████████████████████| 50.4MB 59kB/s
# ...
#      |████████████████████████████████| 3.0MB 37.5MB/s
# ...
#      |████████████████████████████████| 645kB 36.6MB/s
# ...
#      |████████████████████████████████| 27.4MB 111kB/s
# Requirement already up-to-date: torch>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 10)) (1.8.1+cu101)
# Requirement already up-to-date: torchvision>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 11)) (0.9.1+cu101)
# ...
#      |████████████████████████████████| 81kB 8.6MB/s
# Requirement already up-to-date: tensorboard>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 15)) (2.4.1)
# Requirement already up-to-date: seaborn>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 19)) (0.11.1)
# ...

# %%
# !unzip ./Desktop.zip
# Out:
# Archive:  ./Desktop.zip
#    creating: imges/
#    creating: imges/train/
#   inflating: imges/train/0.jpg
#   inflating: imges/train/1.jpg
#   inflating: imges/train/10.jpg
#   inflating: imges/train/11.jpg
#   inflating: imges/train/12.jpg
#   inflating: imges/train/13.jpg
#   inflating: imges/train/14.jpg
#   inflating: imges/train/15.jpg
#   inflating: imges/train/16.jpg
#   inflating: imges/train/18.jpg
#   inflating: imges/train/19.jpg
#   inflating: imges/train/2.jpg
#   inflating: imges/train/20.jpg
#   inflating: imges/train/21.jpg
#   inflating: imges/train/22.jpg
#   inflating: imges/train/23.jpg
#   inflating: imges/train/24.jpg
#   inflating: imges/train/25.jpg
#   inflating: imges/train/27.jpg
#   inflating: imges/train/28.jpg
#   inflating: imges/train/29.jpg
#   inflating: imges/train/3.jpg
#   inflating: imges/train/30.jpg
#   inflating: imges/train/31.jpg
#   inflating: imges/train/32.jpg
#   inflating: imges/train/33.jpg
#   inflating: imges/train/35.jpg
# ...

# %%
cd ..
# Out:
# /content/drive/MyDrive/yolo

# %%
ll
# Out:
# total 5887
# -rw------- 1 root 6015153 Apr  5 16:55 Desktop.zip
# drwx------ 4 root    4096 Apr  6  2021 imges/
# drwx------ 4 root    4096 Apr  6  2021 labels/
# drwx------ 8 root    4096 Apr  5 17:01 yolov5/

# %%
cp ./yolov5/data/coco.yaml ./harm.yaml

# %%
# !bash ./yolov5/weights/download_weights.sh
# Out:
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# ModuleNotFoundError: No module named 'utils'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd yolov5/
# Out:
# /content/drive/MyDrive/yolo/yolov5

# %%
cd ..
# Out:
# /content/drive/My Drive/yolo

# %%
# !mkdir ./test/train
# !mkdir ./test/val

# %%
# !mv ./test/imges test/train/
# !mv ./test/labels test/train/

# %%
# !mkdir ./test/train/images
# !mkdir ./test/train/labels
# !mkdir ./test/val/images
# !mkdir ./test/val/labels

# %%
# !rm -fr test/val/

# %%
# !mv ./imges/train/* ./test/train/images/
# !mv ./imges/val/* ./test/val/images/
# !mv ./labels/train/* ./test/train/labels/
# !mv ./labels/val/* ./test/val/labels

# %%
# !python ./train.py --data ../test/harm.yaml --weights ./weights/yolov5s.pt --batch-size 64
# Out:
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 20 (delta 11), reused 5 (delta 4), pack-reused 0
# Unpacking objects: 100% (20/20), done.
# From https://github.com/ultralytics/yolov5
#    9ccfa85..c8c8da6  master               -> origin/master
#  * [new branch]      glenn-jocher-patch-4 -> origin/glenn-jocher-patch-4
# github: ⚠️ WARNING: code is out of date by 4 commits. Use 'git pull' to update or 'git clone https://github.com/ultralytics/yolov5' to download latest.
# YOLOv5 🚀 v4.0-184-g9ccfa85 torch 1.8.1+cu101 CUDA:0 (Tesla K80, 11441.1875MB)
#
# ...

# %%
# !python detect.py --img 640 --weight runs/train/exp6/weights/best.pt --source /content/drive/MyDrive/yolo/imges/123.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='/content/drive/MyDrive/yolo/imges/123.jpg', update=False, view_img=False, weights=['runs/train/exp6/weights/best.pt'])
# YOLOv5 🚀 v4.0-184-g9ccfa85 torch 1.8.1+cu101 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPS
# image 1/1 /content/drive/MyDrive/yolo/imges/123.jpg: 480x640 1 harm, Done. (0.032s)
# Results saved to runs/detect/exp
# Done. (0.057s)

# %%
# !rm -rf ./runs/detect/exp*
